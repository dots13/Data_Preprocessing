# %%
import numpy as np
import pandas as pd

import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.rc('figure', figsize=(12, 8))

# %%
#Load the task_data.csv dataset (with data description in task_data_description.txt).

# %%
df = pd.read_csv('task_data.csv')

# %%
df.nunique()
# Out:
# Id               1460
# MSSubClass         15
# MSZoning            5
# LotFrontage       110
# LotArea          1073
# Street              2
# Alley               2
# LotShape            4
# LandContour         4
# Utilities           2
# LotConfig           5
# LandSlope           3
# Neighborhood       25
# Condition1          9
# Condition2          8
# BldgType            5
# HouseStyle          8
# OverallQual        10
# OverallCond         9
# YearBuilt         112
# YearRemodAdd       61
# RoofStyle           6
# RoofMatl            8
# Exterior1st        15
# Exterior2nd        16
# MasVnrType          4
# MasVnrArea        327
# ExterQual           4
# ExterCond           5
# Foundation          6
#                  ...
# BedroomAbvGr        8
# KitchenAbvGr        4
# KitchenQual         4
# TotRmsAbvGrd       12
# Functional          7
# Fireplaces          4
# FireplaceQu         5
# GarageType          6
# GarageYrBlt        97
# GarageFinish        3
# GarageCars          5
# GarageArea        441
# GarageQual          5
# GarageCond          5
# PavedDrive          3
# WoodDeckSF        274
# OpenPorchSF       202
# EnclosedPorch     120
# 3SsnPorch          20
# ScreenPorch        76
# PoolArea            8
# PoolQC              3
# Fence               4
# MiscFeature         4
# MiscVal            21
# MoSold             12
# YrSold              5
# SaleType            9
# SaleCondition       6
# SalePrice         663
# Length: 81, dtype: int64

# %%
#Select at least 2 features with nominal scale, 1 with dichotomous scale, 2 with ordinal scale, 
#2 with discrete numeric scale, and 2 with numeric continuous scale.

# %%
#Data types & measurement scales
#        Nominal - MSZoning, Street, RoofStyle, RoofMatl
#        Dichotomous - CentralAir
#        Ordinal (string or int) - Utilities, PavedDrive
#        Numeric discrete (int) - OverallQual, OverallCond
#        Numeric continuous (interval/ratio) (float) - GrLivArea,SalePrice

# %% [markdown]
# *** komentář *** OverallQual je spíš Ordinal než numeric discrete

# %% [markdown]
# **addition**
# Thanks. There are only two features with int value in the base. Is it mean, that  numeric discrete only OverallCond?

# %%
df2 = df[['Street', 'MSZoning', 'Utilities', 'PavedDrive', 'OverallQual', 'OverallCond', 'RoofStyle', 'RoofMatl', 'CentralAir', 
    'GrLivArea', 'SalePrice']]

# %%
#Validate domains of all those selected features.

# %%
df2.nunique()
# Out:
# Street           2
# MSZoning         5
# Utilities        2
# PavedDrive       3
# OverallQual     10
# OverallCond      9
# RoofStyle        6
# RoofMatl         8
# CentralAir       2
# GrLivArea      861
# SalePrice      663
# dtype: int64

# %%
df2.describe()
# Out:
#        OverallQual  OverallCond    GrLivArea      SalePrice
# count  1460.000000  1460.000000  1460.000000    1460.000000
# mean      6.099315     5.575342  1515.463699  180921.195890
# std       1.382997     1.112799   525.480383   79442.502883
# min       1.000000     1.000000   334.000000   34900.000000
# 25%       5.000000     5.000000  1129.500000  129975.000000
# 50%       6.000000     5.000000  1464.000000  163000.000000
# 75%       7.000000     6.000000  1776.750000  214000.000000
# max      10.000000     9.000000  5642.000000  755000.000000

# %%
df2.Street.unique()
# Out:
# array(['Pave', 'Grvl'], dtype=object)

# %%
df2.MSZoning.unique()
# Out:
# array(['RL', 'RM', 'C (all)', 'FV', 'RH'], dtype=object)

# %%
df2.Utilities.unique()
# Out:
# array(['AllPub', 'NoSeWa'], dtype=object)

# %%
df2.RoofStyle.unique()
# Out:
# array(['Gable', 'Hip', 'Gambrel', 'Mansard', 'Flat', 'Shed'], dtype=object)

# %%
df2.RoofMatl.unique()
# Out:
# array(['CompShg', 'WdShngl', 'Metal', 'WdShake', 'Membran', 'Tar&Grv',
#        'Roll', 'ClyTile'], dtype=object)

# %%
df2.CentralAir.unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
#Convert them to proper format.

# %%
df2.Utilities.unique()
df2.Utilities = df2.Utilities.astype('category', categories = ['AllPub', 'NoSeWa'], ordered = False)
# Out:
# D:\Anaconda\lib\site-packages\pandas\core\generic.py:3110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
df2.MSZoning = df2.MSZoning.astype('category', categories = ['RL', 'RM', 'C (all)', 'FV', 'RH'], ordered = False)
# Out:
# D:\Anaconda\lib\site-packages\pandas\core\generic.py:3110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
df2.PavedDrive = df2.PavedDrive.astype('category', categories = ['Y', 'P', 'N'], ordered = True)
# Out:
# D:\Anaconda\lib\site-packages\pandas\core\generic.py:3110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
display(df2['PavedDrive'].unique())
# Out:
# [Y, N, P]
# Categories (3, object): [Y < P < N]

# %%
df2.CentralAir = df2.CentralAir.astype('category', categories = ['Y', 'N'], ordered = False)
# Out:
# D:\Anaconda\lib\site-packages\pandas\core\generic.py:3110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
#The next part just for interested

# %%
Roof_St = {'Gable': 0, 'Hip': 1, 'Gambrel': 2, 'Mansard': 3, 'Flat': 4, 'Shed': 5}
df2["RoofStyle"] = df2["RoofStyle"].apply(lambda s: Roof_St.get(s))
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Roof_Mat = {'CompShg': 0, 'WdShngl': 1, 'Metal': 2, 'WdShake': 3, 'Membran': 4, 'Tar&Grv': 5, 'Roll':6, 'ClyTile':7}
df2["RoofMatl"] = df2["RoofMatl"].apply(lambda s: Roof_Mat.get(s))
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 11 columns):
# Street         1460 non-null object
# MSZoning       1460 non-null category
# Utilities      1460 non-null category
# PavedDrive     1460 non-null category
# OverallQual    1460 non-null int64
# OverallCond    1460 non-null int64
# RoofStyle      1460 non-null int64
# RoofMatl       1460 non-null int64
# CentralAir     1460 non-null category
# GrLivArea      1460 non-null int64
# SalePrice      1460 non-null int64
# dtypes: category(4), int64(6), object(1)
# memory usage: 86.1+ KB

# %%
df2.describe()
# Out:
#        OverallQual  OverallCond    RoofStyle     RoofMatl    GrLivArea  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean      6.099315     5.575342     0.267808     0.065068  1515.463699
# std       1.382997     1.112799     0.611903     0.539603   525.480383
# min       1.000000     1.000000     0.000000     0.000000   334.000000
# 25%       5.000000     5.000000     0.000000     0.000000  1129.500000
# 50%       6.000000     5.000000     0.000000     0.000000  1464.000000
# 75%       7.000000     6.000000     0.000000     0.000000  1776.750000
# max      10.000000     9.000000     5.000000     7.000000  5642.000000
#
#            SalePrice
# count    1460.000000
# mean   180921.195890
# std     79442.502883
# min     34900.000000
# 25%    129975.000000
# 50%    163000.000000
# 75%    214000.000000
# max    755000.000000

# %%
#Try to detect some outliers (hint: use GrLivArea and SalePrice).

# %%
sns.boxplot(y='GrLivArea', data=df2)

# %%
sns.boxplot(y='SalePrice', data=df2)

# %%
Q1 = df2.quantile(0.25)
Q3 = df2.quantile(0.75)
IQR = Q3 - Q1

# %%
df2.GrLivArea[(df['GrLivArea'] > Q3['GrLivArea'] + 1.5*IQR['GrLivArea']) | (df['GrLivArea'] < Q1['GrLivArea'] - 
                                                                       1.5*IQR['GrLivArea'])]
# Out:
# 58      2945
# 118     3222
# 185     3608
# 197     3112
# 231     2794
# 304     3493
# 324     2978
# 496     3228
# 523     4676
# 583     2775
# 608     3194
# 635     3395
# 691     4316
# 769     3279
# 798     3140
# 803     2822
# 961     2872
# 1024    2898
# 1031    3082
# 1046    2868
# 1142    2828
# 1169    3627
# 1173    3086
# 1175    2872
# 1182    4476
# 1268    3447
# 1298    5642
# 1312    2810
# 1328    2792
# 1353    3238
# 1386    2784
# Name: GrLivArea, dtype: int64

# %%
df2.iloc[df2.SalePrice[(df['SalePrice'] > Q3['SalePrice'] + 1.5*IQR['SalePrice']) | (df['SalePrice'] < Q1['SalePrice'] - 
                                                                            1.5*IQR['SalePrice'])].iloc[-5:].keys()]
# Out:
#      Street MSZoning Utilities PavedDrive  OverallQual  OverallCond  \
# 1268   Pave       RL    AllPub          Y            8            9
# 1353   Pave       RL    AllPub          Y            8            5
# 1373   Pave       RL    AllPub          Y           10            5
# 1388   Pave       RL    AllPub          Y            9            5
# 1437   Pave       RL    AllPub          Y            8            5
#
#       RoofStyle  RoofMatl CentralAir  GrLivArea  SalePrice
# 1268          0         0          Y       3447     381000
# 1353          1         0          Y       3238     410000
# 1373          1         0          Y       2633     466500
# 1388          0         0          Y       1746     377500
# 1437          1         0          Y       1932     394617

# %%
sns.jointplot(x='SalePrice', y='GrLivArea', data = df2, kind="hex")

# %% [markdown]
# *** komentář *** Jsou tam nějací outliers?

# %% [markdown]
# ***addition***

# %%
# Outliers were better seen on boxplots. For GrLivArea the value over 3000 (near) and for price over 300000. 
# In tables higher showing which rows are outliers.

# %% [markdown]
# ***Make jointplot without outliers.***

# %%
df_without_outlier = df2.drop(df2.SalePrice[(df['SalePrice'] > (Q3['SalePrice'] + 1.5*IQR['SalePrice'])) | (df['SalePrice'] < Q1['SalePrice'] - 
                                                                            1.5*IQR['SalePrice'])].index)

# %%
df_without_outlier = df2.drop(df2.GrLivArea[(df['GrLivArea'] > (Q3['GrLivArea'] + 1.5*IQR['GrLivArea'])) | (df['GrLivArea'] < Q1['GrLivArea'] - 
                                                                       1.5*IQR['GrLivArea'])].index)

# %%
sns.jointplot(x='SalePrice', y='GrLivArea', data = df_without_outlier, kind="hex")

# %%
#Determine all features with missing data.

# %%
df.isnull().sum().sort_values()[-20:]
# Out:
# Utilities          0
# Electrical         1
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtFinType1      37
# BsmtFinType2      38
# BsmtExposure      38
# GarageQual        81
# GarageFinish      81
# GarageYrBlt       81
# GarageType        81
# GarageCond        81
# LotFrontage      259
# FireplaceQu      690
# Fence           1179
# Alley           1369
# MiscFeature     1406
# PoolQC          1453
# dtype: int64

# %%
#Find a feature that should be completely droped from further analysis.

# %%
##Drop 3 features with the biggedt sum missing values -Alley, MiscFeature, PoolQC

# %%
df = df.drop(df.isnull().mean().sort_values().iloc[-3:].keys(), 1)

# %%
# here in %

# %%
df.isnull().mean().sort_values()[-5:]
# Out:
# GarageType     0.055479
# GarageCond     0.055479
# LotFrontage    0.177397
# FireplaceQu    0.472603
# Fence          0.807534
# dtype: float64

# %%
#Select a feature with reasonable small portion of missing values (but with at least 5) and try to fill it properly.

# %%
df.MasVnrType.value_counts()
# Out:
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64

# %%
df[df.MasVnrType.isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 234    235          60       RL          NaN     7851   Pave      Reg
# 529    530          20       RL          NaN    32668   Pave      IR1
# 650    651          60       FV         65.0     8125   Pave      Reg
# 936    937          20       RL         67.0    10083   Pave      Reg
# 973    974          20       FV         95.0    11639   Pave      Reg
# 977    978         120       FV         35.0     4274   Pave      IR1
# 1243  1244          20       RL        107.0    13891   Pave      Reg
# 1278  1279          60       RL         75.0     9473   Pave      Reg
#
#      LandContour Utilities LotConfig    ...     3SsnPorch ScreenPorch  \
# 234          Lvl    AllPub    Inside    ...             0           0
# 529          Lvl    AllPub   CulDSac    ...             0           0
# 650          Lvl    AllPub    Inside    ...             0           0
# 936          Lvl    AllPub    Inside    ...             0           0
# 973          Lvl    AllPub    Corner    ...             0           0
# 977          Lvl    AllPub    Inside    ...             0           0
# 1243         Lvl    AllPub    Inside    ...             0           0
# 1278         Lvl    AllPub    Inside    ...             0           0
#
#      PoolArea Fence MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 234         0   NaN       0      5    2010        WD         Normal     216500
# 529         0   NaN       0      3    2007        WD         Alloca     200624
# 650         0   NaN       0      5    2008        WD         Normal     205950
# 936         0   NaN       0      8    2009        WD         Normal     184900
# 973         0   NaN       0     12    2008       New        Partial     182000
# 977         0   NaN       0     11    2007       New        Partial     199900
# 1243        0   NaN       0      9    2006       New        Partial     465000
# 1278        0   NaN       0      3    2008        WD         Normal     237000
#
# [8 rows x 78 columns]

# %%
# Impute values based on SalePrice for example
# None value is the most popular
table = pd.crosstab(df.SalePrice, df.MasVnrType, margins=True)
display(table)
table2 = table.mul(100).floordiv(table.iloc[:,-1], axis=0).astype(str) + '%'
display(table2)
# Out:
# MasVnrType  BrkCmn  BrkFace  None  Stone   All
# SalePrice
# 34900            0        0     1      0     1
# 35311            0        0     1      0     1
# 37900            0        0     1      0     1
# 39300            0        0     1      0     1
# 40000            0        0     1      0     1
# 52000            0        0     1      0     1
# 52500            0        0     1      0     1
# 55000            0        0     2      0     2
# 55993            0        0     1      0     1
# 58500            0        0     1      0     1
# 60000            0        0     3      0     3
# 61000            0        0     1      0     1
# 62383            0        0     1      0     1
# 64500            0        0     1      0     1
# 66500            0        0     1      0     1
# 67000            0        0     2      0     2
# 68400            0        0     1      0     1
# 68500            0        0     1      0     1
# 72500            0        0     1      0     1
# 73000            0        0     1      0     1
# 75000            0        1     0      0     1
# 75500            0        0     1      0     1
# 76000            0        0     1      0     1
# 76500            0        0     1      0     1
# 78000            0        0     1      0     1
# 79000            0        0     3      0     3
# 79500            0        0     1      0     1
# 79900            0        1     1      0     2
# 80000            0        0     4      0     4
# 80500            0        0     1      0     1
# ...            ...      ...   ...    ...   ...
# 395000           0        1     0      0     1
# 395192           0        0     0      1     1
# 402000           0        1     0      0     1
# 402861           0        1     0      0     1
# 403000           0        1     0      0     1
# 410000           0        1     0      0     1
# 412500           0        1     0      0     1
# 415298           0        1     0      0     1
# 423000           0        0     1      0     1
# 424870           0        0     0      1     1
# 426000           0        0     0      1     1
# 430000           0        0     1      0     1
# 437154           0        1     0      0     1
# 438780           0        1     0      0     1
# 440000           0        1     0      0     1
# 446261           0        0     0      1     1
# 451950           0        0     0      1     1
# 466500           0        1     0      0     1
# 475000           0        0     1      0     1
# 485000           0        0     0      1     1
# 501837           0        0     0      1     1
# 538000           0        1     0      0     1
# 555000           0        0     0      1     1
# 556581           0        0     0      1     1
# 582933           0        0     0      1     1
# 611657           0        0     0      1     1
# 625000           0        1     0      0     1
# 745000           0        0     1      0     1
# 755000           0        1     0      0     1
# All             15      445   864    128  1452
#
# [658 rows x 5 columns]
# MasVnrType BrkCmn BrkFace  None Stone   All
# SalePrice
# 34900          0%      0%  100%    0%  100%
# 35311          0%      0%  100%    0%  100%
# 37900          0%      0%  100%    0%  100%
# 39300          0%      0%  100%    0%  100%
# 40000          0%      0%  100%    0%  100%
# 52000          0%      0%  100%    0%  100%
# 52500          0%      0%  100%    0%  100%
# 55000          0%      0%  100%    0%  100%
# 55993          0%      0%  100%    0%  100%
# 58500          0%      0%  100%    0%  100%
# 60000          0%      0%  100%    0%  100%
# 61000          0%      0%  100%    0%  100%
# 62383          0%      0%  100%    0%  100%
# 64500          0%      0%  100%    0%  100%
# 66500          0%      0%  100%    0%  100%
# 67000          0%      0%  100%    0%  100%
# 68400          0%      0%  100%    0%  100%
# 68500          0%      0%  100%    0%  100%
# 72500          0%      0%  100%    0%  100%
# 73000          0%      0%  100%    0%  100%
# 75000          0%    100%    0%    0%  100%
# 75500          0%      0%  100%    0%  100%
# 76000          0%      0%  100%    0%  100%
# 76500          0%      0%  100%    0%  100%
# 78000          0%      0%  100%    0%  100%
# 79000          0%      0%  100%    0%  100%
# 79500          0%      0%  100%    0%  100%
# 79900          0%     50%   50%    0%  100%
# 80000          0%      0%  100%    0%  100%
# 80500          0%      0%  100%    0%  100%
# ...           ...     ...   ...   ...   ...
# 395000         0%    100%    0%    0%  100%
# 395192         0%      0%    0%  100%  100%
# 402000         0%    100%    0%    0%  100%
# 402861         0%    100%    0%    0%  100%
# 403000         0%    100%    0%    0%  100%
# 410000         0%    100%    0%    0%  100%
# 412500         0%    100%    0%    0%  100%
# 415298         0%    100%    0%    0%  100%
# 423000         0%      0%  100%    0%  100%
# 424870         0%      0%    0%  100%  100%
# 426000         0%      0%    0%  100%  100%
# 430000         0%      0%  100%    0%  100%
# 437154         0%    100%    0%    0%  100%
# 438780         0%    100%    0%    0%  100%
# 440000         0%    100%    0%    0%  100%
# 446261         0%      0%    0%  100%  100%
# 451950         0%      0%    0%  100%  100%
# 466500         0%    100%    0%    0%  100%
# 475000         0%      0%  100%    0%  100%
# 485000         0%      0%    0%  100%  100%
# 501837         0%      0%    0%  100%  100%
# 538000         0%    100%    0%    0%  100%
# 555000         0%      0%    0%  100%  100%
# 556581         0%      0%    0%  100%  100%
# 582933         0%      0%    0%  100%  100%
# 611657         0%      0%    0%  100%  100%
# 625000         0%    100%    0%    0%  100%
# 745000         0%      0%  100%    0%  100%
# 755000         0%    100%    0%    0%  100%
# All            1%     30%   59%    8%  100%
#
# [658 rows x 5 columns]

# %%
# df.MasVnrType = df.MasVnrType.fillna('None')

# %% [markdown]
# *** komentář *** None není vysloveně špatně, ale šlo by to lépe založit na Exterior1st

# %% [markdown]
# *** addition ***

# %%
table = pd.crosstab(df.Exterior1st, df.MasVnrType, margins=True)
display(table)
table2 = table.mul(100).floordiv(table.iloc[:,-1], axis=0).astype(str) + '%'
display(table2)
# Out:
# MasVnrType   BrkCmn  BrkFace  None  Stone   All
# Exterior1st
# AsbShng           0        1    18      1    20
# AsphShn           0        0     1      0     1
# BrkComm           0        0     2      0     2
# BrkFace           0        0    49      1    50
# CBlock            0        0     1      0     1
# CemntBd           0       12    30     17    59
# HdBoard           3      110   102      7   222
# ImStucc           0        0     1      0     1
# MetalSd           2       58   155      5   220
# Plywood           1       43    61      3   108
# Stone             0        0     2      0     2
# Stucco            1        3    20      1    25
# VinylSd           2      177   240     91   510
# Wd Sdng           5       37   162      1   205
# WdShing           1        4    20      1    26
# All              15      445   864    128  1452
# MasVnrType  BrkCmn BrkFace  None Stone   All
# Exterior1st
# AsbShng         0%      5%   90%    5%  100%
# AsphShn         0%      0%  100%    0%  100%
# BrkComm         0%      0%  100%    0%  100%
# BrkFace         0%      0%   98%    2%  100%
# CBlock          0%      0%  100%    0%  100%
# CemntBd         0%     20%   50%   28%  100%
# HdBoard         1%     49%   45%    3%  100%
# ImStucc         0%      0%  100%    0%  100%
# MetalSd         0%     26%   70%    2%  100%
# Plywood         0%     39%   56%    2%  100%
# Stone           0%      0%  100%    0%  100%
# Stucco          4%     12%   80%    4%  100%
# VinylSd         0%     34%   47%   17%  100%
# Wd Sdng         2%     18%   79%    0%  100%
# WdShing         3%     15%   76%    3%  100%
# All             1%     30%   59%    8%  100%

# %%
#'None' here is also most probable one. 
#I was trying to find how to fill missing (string)values using a probabilistic. Are there any methods how to fill value with
# most expected value? Or it's not very useful?

# %%
df.MasVnrType = df.MasVnrType.fillna('None')
